# %%
import nltk
import urllib.request
from bs4 import BeautifulSoup
from nltk.corpus import stopwords

# %%
response = urllib.request.urlopen('https://dolly.com/blog/best-washington-dc-neighborhoods/')
html = response.read()

# %%
soup = BeautifulSoup(html,'xml') 
text = soup.get_text(strip = True) 
print(text)
# Out:
# A Guide to the Best Washington, DC Neighborhoods | Dolly Blog{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://dolly.com/blog/#website","url":"https://dolly.com/blog/","name":"Unboxed","description":"Your Place for Creative Moving & Delivery Ideas","potentialAction":[{"@type":"SearchAction","target":"https://dolly.com/blog/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#primaryimage","inLanguage":"en-US","url":"https://dolly.com/blog/wp-content/uploads/2018/09/lafayette-park-washington-dc-c-architecture-161768.jpeg","width":1280,"height":1361},{"@type":"WebPage","@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#webpage","url":"https://dolly.com/blog/best-washington-dc-neighborhoods/","name":"A Guide to the Best Washington, DC Neighborhoods | Dolly Blog","isPartOf":{"@id":"https://dolly.com/blog/#website"},"primaryImageOfPage":{"@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#primaryimage"},"datePublished":"2018-10-01T23:26:48+00:00","dateModified":"2018-10-01T23:26:48+00:00","author":{"@id":"https://dolly.com/blog/#/schema/person/1f8cfa915c15a5a46ca7d03830656d62"},"description":"From Foggy Bottom to River Terrace, there are plenty of beautiful places to call home in DC. These are our favorite Washington, DC neighborhoods.","inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://dolly.com/blog/best-washington-dc-neighborhoods/"]}]},{"@type":"Person","@id":"https://dolly.com/blog/#/schema/person/1f8cfa915c15a5a46ca7d03830656d62","name":"Miranda N. Benson","image":{"@type":"ImageObject","@id":"https://dolly.com/blog/#personlogo","inLanguage":"en-US","url":"https://secure.gravatar.com/avatar/b616cb05a298308d2ddc14d24302b278?s=96=mm=g","caption":"Miranda N. Benson"},"description":"Miranda is the Marketing Coordinator at Dolly. She's moved nine times in the past six years, and while she's grateful for the moving expertise, she's hoping she doesn't need to move a tenth time anytime soon.","sameAs":["https://www.linkedin.com/in/mirandanbenson/"]}]}window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/dolly.com\/blog\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.5.1"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything[i[o]],"flag"!==i[o](t.supports.everythingExceptFlag=t.supports.everythingExceptFlag[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }a:hover,
#             .a-primary a,
#             .a-white a:hover,
#             .a-meta a:hover,
#             footer .menu li:after, #menu .menu li:after,
#             #header-menu .current-menu-item a,
#             .color-primary { color: #e7412a; }
#
#
#             ::-moz-selection,
#             ::selection{background-color: #e7412a}
#
#
#             .a-meta a,
#             .logo .tagline,
#             #comments .comment.bypostauthor .thecomment .comment-header .comment-header-text .author,
#             .color-meta { color: #a7a6a6; }
#
#
#
#             a,
#             .a-primary a:hover,
#             body,
#             .color-dark{ color: #232120; }
#
#             input[type=submit]:hover, button:hover,
#             #header-menu .menu-item-has-children .sub-menu,
#             .navigation.pagination .nav-links .current,
#             .background-dark { background-color: #232120; }
#
#             #sidebar .box .box-title:after,
#             #sidebar .box .box-title:before,
#             blockquote, pre, address{border-color: #232120; }(function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1=v2.8";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));MovingTips & TricksNewsStoriesCitiesThe Dolly BlogUnboxedYour Place for Creative Moving  Delivery IdeasCitiesA Guide to the Best Washington, DC NeighborhoodsByMiranda N. BensonOnOctober 1, 2018025Any DC native will gladly tell newcomers the truth: there are many more (and many better) neighborhoods than Capitol Hill. While the city itself is often associated with the politicians that live in the nicest parts of town, most locals live elsewhere, in one of many neighborhoods that make DC unique. From historic rowhouses in Bloomingdale to waterfront views in Foggy Bottom, the Capital boasts plenty of neighborhoods to choose from. Here are some of the best Washington, DC neighborhoods to call home.The Best Washington, DC NeighborhoodsGeorgetownPhoto Source:New York TimesAverage one-bedroom rent:$1,666Walkscore:83A surprisingly metropolitan neighborhood of classic historical homes, Georgetown is perfect for folks looking for city life with plenty of natural feeling. A newly revitalized waterfront on the Potomac River and the Chesapeake and Ohio Canal (now a national park) run parallel to a slew of modern shops and restaurants that perfectly mix the old town feeling with contemporary comforts. And because Georgetown University is in the heart of the neighborhood, there’s plenty of housing for younger (read: cheaper) renters – the only downside is the lack of Metro stops, making it hard to leave this part of town.Dupont CircleImage Source:WashingtonianAverage one-bedroom rent:$2,322Walkscore:98While the tourist in you may associate Dupont Circle with Embassy Row, this neighborhood boasts some great livability (that Walkscore of 98 isn’t an exaggeration) with a five minute commute to downtown and a conveniently located Metro station, plus iconic parks galore. The only downside? Convenience comes at a price, and as one of the most expensive Washington, DC neighborhoods, Dupont Circle’s price to rent is no easy pill to swallow.Navy YardPhoto Source:Gordon James RealtyAverage one-bedroom rent:$2,335Walkscore:84For those seeking a brand-new place, there’s nowhere better to look than Navy Yard. This new neighborhood is quite possibly the fastest growing in DC, and between its proximity to the riverfront, the Nationals Stadium, and the new restaurants and bars opening there every week, it’s not hard to see why. The downside, unsurprisingly, is the cost – new apartment aren’t cheap, especially not in this popular neighborhood.Adams MorganPhoto Source:Our Community NowAverage one-bedroom rent:$2,303Walkscore:95To those who aren’t already familiar with this staple neighborhood, it’s hard to explain Adams Morgan. A unique neighborhood blending vintage vibe-artistry with a culture of activism, Adams Morgan is the perfect place to live if you intend to do more than just sleep there. It may not be the cheapest Washington, DC neighborhood to call home, but for the right kind of resident, life in Adams Morgan is worth it.Foggy Bottom / West EndImage Source:TroverAverage one-bedroom rent:$2,425Walkscore:95Just a few steps from Georgetown and downtown is Foggy Bottom (sometimes referred to as the West End), home to some of DC’s most iconic sights and riverfront views. Set right on the edge of the Potomac, you can’t beat the curb appeal of the many historic homes here, or the convenience. The only downside is that home prices come at a cost – especially if there’s a view – but the quality nightlife and dining options might just make it worth the extra arm and leg you’ll pay in rent.Logan Circle / ShawImage Source:Long and FosterAverage one-bedroom rent:$2,334Walkscore:96The millennial hub that is Logan Circle has plenty to boast about: a walkable neighborhood full of great restaurants and bars, a mix of historic homes that will leave your inner architect drooling and new apartments for those wanting something fresh, and of course, the iconic Logan Circle park in the center of it all. It’s definitely a luxury to  ...
#     			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     			})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     			ga('create', 'UA-47314819-7', 'auto');
#     			ga('send', 'pageview');var sbiajaxurl = "https://dolly.com/blog/wp-admin/admin-ajax.php";.saboxplugin-wrap{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box;border:1px solid #eee;width:100%;clear:both;display:block;overflow:hidden;word-wrap:break-word;position:relative}.saboxplugin-wrap .saboxplugin-gravatar{float:left;padding:20px}.saboxplugin-wrap .saboxplugin-gravatar img{max-width:100px;height:auto;border-radius:0;}.saboxplugin-wrap .saboxplugin-authorname{font-size:18px;line-height:1;margin:20px 0 0 20px;display:block}.saboxplugin-wrap .saboxplugin-authorname a{text-decoration:none}.saboxplugin-wrap .saboxplugin-authorname a:focus{outline:0}.saboxplugin-wrap .saboxplugin-desc{display:block;margin:5px 20px}.saboxplugin-wrap .saboxplugin-desc a{text-decoration:underline}.saboxplugin-wrap .saboxplugin-desc p{margin:5px 0 12px}.saboxplugin-wrap .saboxplugin-web{margin:0 20px 15px;text-align:left}.saboxplugin-wrap .sab-web-position{text-align:right}.saboxplugin-wrap .saboxplugin-web a{color:#ccc;text-decoration:none}.saboxplugin-wrap .saboxplugin-socials{position:relative;display:block;background:#fcfcfc;padding:5px;border-top:1px solid #eee}.saboxplugin-wrap .saboxplugin-socials a svg{width:20px;height:20px}.saboxplugin-wrap .saboxplugin-socials a svg .st2{fill:#fff; transform-origin:center center;}.saboxplugin-wrap .saboxplugin-socials a svg .st1{fill:rgba(0,0,0,.3)}.saboxplugin-wrap .saboxplugin-socials a:hover{opacity:.8;-webkit-transition:opacity .4s;-moz-transition:opacity .4s;-o-transition:opacity .4s;transition:opacity .4s;box-shadow:none!important;-webkit-box-shadow:none!important}.saboxplugin-wrap .saboxplugin-socials .saboxplugin-icon-color{box-shadow:none;padding:0;border:0;-webkit-transition:opacity .4s;-moz-transition:opacity .4s;-o-transition:opacity .4s;transition:opacity .4s;display:inline-block;color:#fff;font-size:0;text-decoration:inherit;margin:5px;-webkit-border-radius:0;-moz-border-radius:0;-ms-border-radius:0;-o-border-radius:0;border-radius:0;overflow:hidden}.saboxplugin-wrap .saboxplugin-socials .saboxplugin-icon-grey{text-decoration:inherit;box-shadow:none;position:relative;display:-moz-inline-stack;display:inline-block;vertical-align:middle;zoom:1;margin:10px 5px;color:#444;fill:#444}.clearfix:after,.clearfix:before{content:' ';display:table;line-height:0;clear:both}.ie7 .clearfix{zoom:1}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-twitch{border-color:#38245c}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-addthis{border-color:#e91c00}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-behance{border-color:#003eb0}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-delicious{border-color:#06c}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-deviantart{border-color:#036824}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-digg{border-color:#00327c}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-dribbble{border-color:#ba1655}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-facebook{border-color:#1e2e4f}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-flickr{border-color:#003576}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-github{border-color:#264874}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-google{border-color:#0b51c5}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-googleplus{border-color:#96271a}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-html5{border-color:#902e13}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-instagram{border-color:#1630aa}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-linkedin{border-color:#00344f}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-pinterest{border-color:#5b040e}.saboxplugin-socials.sabox-colored .saboxplugin-icon-color .sab-reddit{border-color:#99290 ...
# var q2w3_sidebar_options = [{"sidebar":"sidebar","margin_top":10,"margin_bottom":20,"stop_id":"colophon","screen_max_width":0,"screen_max_height":0,"width_inherit":false,"refresh_interval":1500,"window_load_hook":false,"disable_mo_api":false,"widgets":["search-3","creek_latest_posts-2","do-etfw-2","text-2"]}];
# /*  *//*  */
# var sti_vars = {"ajaxurl":"https:\/\/dolly.com\/blog\/wp-admin\/admin-ajax.php","selector":"img","title":"","summary":"","minWidth":"200","minHeight":"200","sharer":"https:\/\/dolly.com\/blog\/wp-content\/plugins\/share-this-image\/sharer.php","is_mobile":"","position":"image_hover","analytics":"","buttons":{"desktop":["facebook","twitter","linkedin","pinterest"],"mobile":["facebook","twitter","linkedin","pinterest"]},"twitterVia":"getdolly","appId":"","custom_data":[]};
# /*  */vices.com/pagead/conversion.js">!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','//connect.facebook.net/en_US/fbevents.js');
# // Insert Your Facebook Pixel ID below.
# fbq('init', '842588449091347');
# fbq('track', 'PageView');defer src="//js.hs-scripts.com/3049473.js">(function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"5038210"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s!=="loaded"!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");

# %%
tokens = [t for t in text.split()] 
print(tokens)
# Out:
# ['A', 'Guide', 'to', 'the', 'Best', 'Washington,', 'DC', 'Neighborhoods', '|', 'Dolly', 'Blog{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://dolly.com/blog/#website","url":"https://dolly.com/blog/","name":"Unboxed","description":"Your', 'Place', 'for', 'Creative', 'Moving', '&', 'Delivery', 'Ideas","potentialAction":[{"@type":"SearchAction","target":"https://dolly.com/blog/?s={search_term_string}","query-input":"required', 'name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#primaryimage","inLanguage":"en-US","url":"https://dolly.com/blog/wp-content/uploads/2018/09/lafayette-park-washington-dc-c-architecture-161768.jpeg","width":1280,"height":1361},{"@type":"WebPage","@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#webpage","url":"https://dolly.com/blog/best-washington-dc-neighborhoods/","name":"A', 'Guide', 'to', 'the', 'Best', 'Washington,', 'DC', 'Neighborhoods', '|', 'Dolly', 'Blog","isPartOf":{"@id":"https://dolly.com/blog/#website"},"primaryImageOfPage":{"@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#primaryimage"},"datePublished":"2018-10-01T23:26:48+00:00","dateModified":"2018-10-01T23:26:48+00:00","author":{"@id":"https://dolly.com/blog/#/schema/person/1f8cfa915c15a5a46ca7d03830656d62"},"description":"From', 'Foggy', 'Bottom', 'to', 'River', 'Terrace,', 'there', 'are', 'plenty', 'of', 'beautiful', 'places', 'to', 'call', 'home', 'in', 'DC.', 'These', 'are', 'our', 'favorite', 'Washington,', 'DC', 'neighborhoods.","inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://dolly.com/blog/best-washington-dc-neighborhoods/"]}]},{"@type":"Person","@id":"https://dolly.com/blog/#/schema/person/1f8cfa915c15a5a46ca7d03830656d62","name":"Miranda', 'N.', 'Benson","image":{"@type":"ImageObject","@id":"https://dolly.com/blog/#personlogo","inLanguage":"en-US","url":"https://secure.gravatar.com/avatar/b616cb05a298308d2ddc14d24302b278?s=96=mm=g","caption":"Miranda', 'N.', 'Benson"},"description":"Miranda', 'is', 'the', 'Marketing', 'Coordinator', 'at', 'Dolly.', "She's", 'moved', 'nine', 'times', 'in', 'the', 'past', 'six', 'years,', 'and', 'while', "she's", 'grateful', 'for', 'the', 'moving', 'expertise,', "she's", 'hoping', 'she', "doesn't", 'need', 'to', 'move', 'a', 'tenth', 'time', 'anytime', 'soon.","sameAs":["https://www.linkedin.com/in/mirandanbenson/"]}]}window._wpemojiSettings', '=', '{"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.0\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.0\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/dolly.com\\/blog\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.5.1"}};', '!function(e,a,t){var', 'r,n,o,i,p=a.createElement("canvas"),s=p.getContext("2d");function', 'c(e,t){var', 'a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var', 'r=p.toDataURL();return', 's.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function', 'l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600', '32px', 'Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function', 'd(e){var', 't=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything[i[o]],"flag"!==i[o](t.supports.everythingExceptF ...

# %%
sr= stopwords.words('english') 
clean_tokens = tokens[:]

for token in tokens:
    if token in stopwords.words('english'): 
        clean_tokens.remove(token)
        
freq = nltk.FreqDist(clean_tokens) 

for key,val in freq.items():
    print(str(key) + ':' + str(val)) 

freq.plot(20, cumulative=False)
# Out:
# A:3
# Guide:5
# Best:8
# Washington,:16
# DC:17
# Neighborhoods:4
# |:2
# Dolly:5
# Blog{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://dolly.com/blog/#website","url":"https://dolly.com/blog/","name":"Unboxed","description":"Your:1
# Place:2
# Creative:2
# Moving:3
# &:4
# Delivery:3
# Ideas","potentialAction":[{"@type":"SearchAction","target":"https://dolly.com/blog/?s={search_term_string}","query-input":"required:1
# name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#primaryimage","inLanguage":"en-US","url":"https://dolly.com/blog/wp-content/uploads/2018/09/lafayette-park-washington-dc-c-architecture-161768.jpeg","width":1280,"height":1361},{"@type":"WebPage","@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#webpage","url":"https://dolly.com/blog/best-washington-dc-neighborhoods/","name":"A:1
# Blog","isPartOf":{"@id":"https://dolly.com/blog/#website"},"primaryImageOfPage":{"@id":"https://dolly.com/blog/best-washington-dc-neighborhoods/#primaryimage"},"datePublished":"2018-10-01T23:26:48+00:00","dateModified":"2018-10-01T23:26:48+00:00","author":{"@id":"https://dolly.com/blog/#/schema/person/1f8cfa915c15a5a46ca7d03830656d62"},"description":"From:1
# Foggy:4
# Bottom:4
# River:3
# Terrace,:2
# plenty:5
# beautiful:1
# places:1
# call:7
# home:7
# DC.:1
# These:1
# favorite:1
# neighborhoods.","inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://dolly.com/blog/best-washington-dc-neighborhoods/"]}]},{"@type":"Person","@id":"https://dolly.com/blog/#/schema/person/1f8cfa915c15a5a46ca7d03830656d62","name":"Miranda:1
# N.:4
# Benson","image":{"@type":"ImageObject","@id":"https://dolly.com/blog/#personlogo","inLanguage":"en-US","url":"https://secure.gravatar.com/avatar/b616cb05a298308d2ddc14d24302b278?s=96=mm=g","caption":"Miranda:1
# Benson"},"description":"Miranda:1
# Marketing:2
# Coordinator:2
# Dolly.:2
# She's:1
# moved:2
# nine:2
# times:2
# past:2
# six:2
# years,:2
# grateful:2
# moving:6
# expertise,:2
# hoping:2
# need:4
# move:6
# tenth:2
# time:3
# anytime:2
# soon.","sameAs":["https://www.linkedin.com/in/mirandanbenson/"]}]}window._wpemojiSettings:1
# =:8
# {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/dolly.com\/blog\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.5.1"}};:1
# !function(e,a,t){var:1
# r,n,o,i,p=a.createElement("canvas"),s=p.getContext("2d");function:1
# c(e,t){var:1
# a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var:1
# r=p.toDataURL();return:1
# s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function:1
# l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600:1
# 32px:1
# Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function:1
# d(e){var:1
# t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything[i[o]],"flag"!==i[o](t.supports.everythingExceptFlag=t.supports.everythingExceptFlag[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);img.wp-smiley,:1
# img.emoji:1
# {:5
# display::1
# inline:1
# !important;:10
# border::1
# none:3
# box-shadow::1
# height::1
# 1em:2
# width::1
# margin::1
# 0:6
# .07em:1
# vertical-align::1
# -0.1em:1
# background::1
# padding::2
# }a:hover,:1
# .a-primary:2
# a,:5
# .a-white:1
# a:hover,:3
# .a-meta:2
# footer:1
# .menu:2
# li:after,:2
# #menu:1
# #header-menu:2
# .current-menu-item:1
# .color-primary:1
# color::3
# #e7412a;:1
# }:4
# ::-moz-selection,:1
# ::selection{background-color::1
# #e7412a}:1
# .logo:1
# .tagline,:1
# #comments:1
# .comment.bypostauthor:1
# .thecomment:1
# .comment-header:1
# .comment-header-text:1
# .author,:1
# .color-meta:1
# #a7a6a6;:1
# body,:1
# .color-dark{:1
# #232120;:3
# input[type=submit]:hover,:1
# button:hover,:1
# .menu-item-has-children:1
# .sub-menu,:1
# .navigation.pagination:1
# .nav-links:1
# .current,:1
# .background-dark:1
# background-color::1
# #sidebar:2
# .box:2
# .box-title:after,:1
# .box-title:before,:1
# blockquote,:1
# pre,:1
# address{border-color::1
# }(function(d,:1
# s,:1
# id):1
# var:3
# js,:1
# fjs:1
# d.getElementsByTagName(s)[0];:1
# (d.getElementById(id)):1
# return;:1
# js:1
# d.createElement(s);:1
# js.id:1
# id;:1
# js.src:1
# "//connect.facebook.net/en_US/sdk.js#xfbml=1=v2.8";:1
# fjs.parentNode.insertBefore(js,:1
# fjs);:1
# }(document,:1
# 'script',:1
# 'facebook-jssdk'));MovingTips:1
# TricksNewsStoriesCitiesThe:1
# BlogUnboxedYour:1
# IdeasCitiesA:1
# NeighborhoodsByMiranda:1
# BensonOnOctober:1
# 1,:3
# 2018025Any:1
# native:1
# gladly:1
# tell:2
# newcomers:1
# truth::1
# many:4
# (and:2
# better):1
# neighborhoods:5
# Capitol:1
# Hill.:1
# While:1
# city:6
# often:1
# associated:1
# politicians:1
# live:4
# nicest:1
# parts:1
# town,:1
# locals:1
# elsewhere,:1
# one:2
# make:4
# unique.:1
# From:2
# historic:3
# rowhouses:1
# Bloomingdale:3
# waterfront:2
# views:1
# Bottom,:1
# Capital:1
# boasts:2
# choose:1
# from.:1
# Here:1
# best:3
# home.The:1
# NeighborhoodsGeorgetownPhoto:1
# Source:New:1
# York:4
# TimesAverage:1
# one-bedroom:11
# rent:$1,666Walkscore:83A:1
# surprisingly:1
# metropolitan:1
# neighborhood:11
# classic:3
# historical:1
# homes,:1
# Georgetown:3
# perfect:3
# folks:1
# looking:1
# life:2
# natural:1
# feeling.:1
# newly:1
# revitalized:1
# Potomac:1
# Chesapeake:1
# Ohio:1
# Canal:1
# (now:1
# national:1
# park):1
# run:1
# parallel:1
# slew:1
# modern:1
# shops:2
# restaurants:3
# perfectly:1
# mix:2
# old:1
# town:1
# feeling:1
# contemporary:1
# comforts.:1
# And:3
# University:1
# heart:2
# neighborhood,:2
# there’s:5
# housing:1
# younger:1
# (read::1
# cheaper):1
# renters:2
# –:9
# downside:2
# lack:1
# Metro:3
# stops,:1
# making:1
# hard:4
# leave:2
# part:1
# town.Dupont:1
# CircleImage:1
# Source:WashingtonianAverage:1
# rent:$2,322Walkscore:98While:1
# tourist:1
# may:3
# associate:1
# Dupont:2
# Circle:4
# Embassy:1
# Row,:1
# great:3
# livability:1
# (that:1
# Walkscore:1
# 98:1
# isn’t:2
# exaggeration):1
# five:1
# minute:1
# commute:1
# downtown:5
# conveniently:1
# located:1
# station,:1
# plus:1
# iconic:3
# parks:2
# galore.:1
# The:4
# downside?:1
# Convenience:1
# comes:1
# price,:1
# expensive:2
# neighborhoods,:2
# Circle’s:1
# price:1
# rent:5
# easy:4
# pill:1
# swallow.Navy:1
# YardPhoto:1
# Source:Gordon:1
# James:1
# RealtyAverage:1
# rent:$2,335Walkscore:84For:1
# seeking:1
# brand-new:1
# place,:1
# nowhere:1
# better:3
# look:2
# Navy:1
# Yard.:1
# This:1
# new:6
# quite:2
# possibly:1
# fastest:1
# growing:2
# DC,:3
# proximity:1
# riverfront,:1
# Nationals:1
# Stadium,:1
# bars:1
# opening:1
# every:1
# week,:1
# it’s:5
# see:1
# why.:1
# downside,:1
# unsurprisingly,:1
# cost:2
# apartment:1
# aren’t:2
# cheap,:1
# especially:2
# popular:1
# neighborhood.Adams:1
# MorganPhoto:1
# Source:Our:1
# Community:1
# NowAverage:1
# rent:$2,303Walkscore:95To:1
# already:1
# familiar:1
# staple:1
# explain:1
# Adams:3
# Morgan.:1
# unique:1
# blending:1
# vintage:1
# vibe-artistry:1
# culture:1
# activism,:1
# Morgan:2
# place:4
# intend:1
# sleep:1
# there.:1
# It:2
# cheapest:1
# home,:2
# right:2
# kind:1
# resident,:1
# worth:3
# it.Foggy:1
# /:4
# West:2
# EndImage:1
# Source:TroverAverage:1
# rent:$2,425Walkscore:95Just:1
# steps:1
# (sometimes:1
# referred:1
# End),:1
# DC’s:2
# sights:1
# riverfront:1
# views.:1
# Set:1
# edge:1
# Potomac,:1
# can’t:1
# beat:1
# curb:1
# appeal:1
# homes:3
# here,:1
# convenience.:1
# prices:1
# come:3
# view:1
# quality:1
# nightlife:2
# dining:1
# options:1
# might:2
# extra:1
# arm:1
# leg:1
# you’ll:1
# pay:1
# rent.Logan:1
# ShawImage:1
# Source:Long:1
# FosterAverage:1
# rent:$2,334Walkscore:96The:1
# millennial:1
# hub:1
# Logan:2
# boast:1
# about::1
# walkable:1
# full:1
# bars,:1
# inner:1
# architect:1
# drooling:1
# apartments:1
# wanting:1
# something:1
# fresh,:1
# course,:1
# park:1
# center:2
# all.:1
# It’s:2
# definitely:1
# luxury:1
# pricey:1
# area,:1
# access:2
# entire:1
# makes:1
# incredibly:1
# it.Need:1
# neighborhood?:1
# Get:1
# on-demand:3
# help:2
# Dolly.Woodley:1
# ParkPhoto:1
# Source:AirbnbAverage:1
# rent:$1,982Walkscore:72More:1
# residential:1
# less:1
# nightlife-heavy:1
# Woodley:1
# Park:1
# ideal:1
# families.:1
# find:2
# spot:2
# home-focused:1
# apartment-oriented:1
# two:1
# massive:1
# quieter:1
# roads:1
# area:1
# quiet:1
# walks:1
# kids:1
# cute:1
# coffee:1
# shop:1
# get:4
# pastries:1
# end).BloomingdalePhoto:1
# Source:ThrillistAverage:1
# rent:$2,355Walkscore:93If:1
# want:4
# Victorian:1
# rowhouse,:1
# home.:1
# But:3
# high:1
# value,:1
# rarely:1
# willing:1
# out.:1
# snag:1
# (or:1
# purchase:1
# own),:1
# break:4
# crowd:1
# would:1
# prefer:1
# quiet,:1
# safe:1
# street.Downtown:1
# Penn:2
# QuarterPhoto:1
# Source:We:1
# Love:1
# DCAverage:1
# rent:$2,360Walkscore:91Living:1
# challenge,:1
# you’re:1
# it,:1
# Quarter.:1
# constantly:1
# crowded:1
# tourists:1
# weekday:1
# workers:1
# alike,:1
# greatest:1
# cultural:1
# hubs:1
# beat.:1
# craziness,:1
# take:1
# anywhere.River:1
# Terrace:1
# MayfairPhoto:1
# Source:Cparkre.comAverage:1
# rent:$970Walkscore:46Not:1
# ready:2
# suburbs,:1
# away:2
# hustle?:1
# urban:1
# development:1
# tucked:1
# corner:1
# crazy:1
# activity:1
# rest:1
# mention:1
# sky-high:1
# prices.:1
# feel:1
# much:1
# like:1
# suburb:1
# center::1
# drive:1
# downtown,:1
# grocery:1
# store,:1
# anywhere:1
# neighbor’s:1
# house.BrooklandImage:1
# Source:FlickrAverage:1
# rent:$1,562Walkscore:75Don’t:1
# anyone,:1
# Brookland:1
# best-kept:1
# secret:1
# neighborhoods.:1
# Low:1
# rent,:1
# low:1
# population:1
# density,:1
# food:1
# H:1
# Street:1
# charming:1
# fast-growing:1
# well:1
# suited:1
# families:1
# young:1
# alike.Once:1
# you’ve:1
# decided:1
# packing.:1
# day,:1
# thanDolly.:1
# We’ll:1
# connect:1
# local:1
# pickup:1
# truck:1
# owners:1
# wherever:1
# to,:1
# whenever:1
# to.:1
# more,Dollyis:1
# way:1
# DC.Walkscore:1
# data:2
# fromwalkscore.com.Rent:1
# fromrentcafe.com.025itemprop="author">Miranda:1
# BensonMiranda:1
# She’s:1
# she’s:2
# doesn’t:1
# soon.Tags:dc,Featured,neighborhood:1
# guide,washington:1
# dcRelated:1
# PostsCitiesDolly:1
# Expanding:2
# New:3
# City!Dolly:1
# expanded:1
# City.:1
# delivery:2
# available:2
# Manhattan,:1
# Bronx,:1
# Long…ByDollyOnOctober:1
# 2020CitiesYour:2
# 10:3
# Chicagobest:1
# ChicagoByDollyOnJanuary:1
# 31,:1
# 2020Announcements,CitiesDolly:1
# Arrives:1
# Milwaukee﻿Dolly:1
# arrived:1
# “coolest:1
# state:1
# midwest“!:1
# Milwaukee…ByDollyOnJanuary:1
# 9,:1
# AtlantaAtlanta:1
# vibrant:1
# bursting:1
# culture,:1
# flavors,:1
# art.:1
# Located:1
# within:1
# Georgia,:1
# impact…ByDollyOnDecember:1
# 30,:1
# 2019SearchRecent:1
# PostsDolly:1
# City!October:1
# 20206:1
# Money-Savvy:1
# Tips:1
# Buying:1
# Quality:1
# Furniture:2
# Value:1
# City:1
# FurnitureMarch:1
# 24,:1
# 202010:1
# Costco:1
# Patio:1
# Sets/Pieces:1
# That:1
# Will:1
# Impress:1
# Your:4
# Whole:1
# NeighborhoodMarch:1
# 14,:1
# 2020The:2
# Farmhouse:1
# Wall:1
# Decor:1
# Ideas:1
# Designs:1
# HomeFebruary:2
# 28,:1
# Top:1
# Container:1
# Store:1
# Products:1
# 25,:1
# 2020Follow:1
# UsTweets:1
# @getDollyWatchAboutCareersContact:1
# UsPressFAQServicesCitiesPartnersHelpersBlogBook:1
# Dolly2020:1
# DollyTermsPrivacyEmail:blog@dolly.comProudly:1
# powered:1
# WordPress(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){:1
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new:1
# Date();a=s.createElement(o),:1
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m):1
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');:1
# ga('create',:1
# 'UA-47314819-7',:1
# 'auto');:1
# ga('send',:1
# 'pageview');var:1
# sbiajaxurl:1
# "https://dolly.com/blog/wp-admin/admin-ajax.php";.saboxplugin-wrap{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box;border:1px:1
# solid:2
# #eee;width:100%;clear:both;display:block;overflow:hidden;word-wrap:break-word;position:relative}.saboxplugin-wrap:1
# .saboxplugin-gravatar{float:left;padding:20px}.saboxplugin-wrap:1
# .saboxplugin-gravatar:2
# img{max-width:100px;height:auto;border-radius:0;}.saboxplugin-wrap:1
# .saboxplugin-authorname{font-size:18px;line-height:1;margin:20px:1
# 20px;display:block}.saboxplugin-wrap:1
# .saboxplugin-authorname:8
# a{text-decoration:none}.saboxplugin-wrap:1
# a:focus{outline:0}.saboxplugin-wrap:1
# .saboxplugin-desc{display:block;margin:5px:1
# 20px}.saboxplugin-wrap:1
# .saboxplugin-desc:6
# a{text-decoration:underline}.saboxplugin-wrap:1
# p{margin:5px:1
# 12px}.saboxplugin-wrap:1
# .saboxplugin-web{margin:0:1
# 20px:1
# 15px;text-align:left}.saboxplugin-wrap:1
# .sab-web-position{text-align:right}.saboxplugin-wrap:1
# .saboxplugin-web:2
# a{color:#ccc;text-decoration:none}.saboxplugin-wrap:1
# .saboxplugin-socials{position:relative;display:block;background:#fcfcfc;padding:5px;border-top:1px:1
# #eee}.saboxplugin-wrap:1
# .saboxplugin-socials:8
# svg{width:20px;height:20px}.saboxplugin-wrap:1
# svg:3
# .st2{fill:#fff;:1
# transform-origin:center:1
# center;}.saboxplugin-wrap:1
# .st1{fill:rgba(0,0,0,.3)}.saboxplugin-wrap:1
# a:hover{opacity:.8;-webkit-transition:opacity:1
# .4s;-moz-transition:opacity:2
# .4s;-o-transition:opacity:2
# .4s;transition:opacity:2
# .4s;box-shadow:none!important;-webkit-box-shadow:none!important}.saboxplugin-wrap:1
# .saboxplugin-icon-color{box-shadow:none;padding:0;border:0;-webkit-transition:opacity:1
# .4s;display:inline-block;color:#fff;font-size:0;text-decoration:inherit;margin:5px;-webkit-border-radius:0;-moz-border-radius:0;-ms-border-radius:0;-o-border-radius:0;border-radius:0;overflow:hidden}.saboxplugin-wrap:1
# .saboxplugin-icon-grey{text-decoration:inherit;box-shadow:none;position:relative;display:-moz-inline-stack;display:inline-block;vertical-align:middle;zoom:1;margin:10px:1
# 5px;color:#444;fill:#444}.clearfix:after,.clearfix:before{content:':1
# ';display:table;line-height:0;clear:both}.ie7:1
# .clearfix{zoom:1}.saboxplugin-socials.sabox-colored:1
# .saboxplugin-icon-color:44
# .sab-twitch{border-color:#38245c}.saboxplugin-socials.sabox-colored:1
# .sab-addthis{border-color:#e91c00}.saboxplugin-socials.sabox-colored:1
# .sab-behance{border-color:#003eb0}.saboxplugin-socials.sabox-colored:1
# .sab-delicious{border-color:#06c}.saboxplugin-socials.sabox-colored:1
# .sab-deviantart{border-color:#036824}.saboxplugin-socials.sabox-colored:1
# .sab-digg{border-color:#00327c}.saboxplugin-socials.sabox-colored:1
# .sab-dribbble{border-color:#ba1655}.saboxplugin-socials.sabox-colored:1
# .sab-facebook{border-color:#1e2e4f}.saboxplugin-socials.sabox-colored:1
# .sab-flickr{border-color:#003576}.saboxplugin-socials.sabox-colored:1
# .sab-github{border-color:#264874}.saboxplugin-socials.sabox-colored:1
# .sab-google{border-color:#0b51c5}.saboxplugin-socials.sabox-colored:1
# .sab-googleplus{border-color:#96271a}.saboxplugin-socials.sabox-colored:1
# .sab-html5{border-color:#902e13}.saboxplugin-socials.sabox-colored:1
# .sab-instagram{border-color:#1630aa}.saboxplugin-socials.sabox-colored:1
# .sab-linkedin{border-color:#00344f}.saboxplugin-socials.sabox-colored:1
# .sab-pinterest{border-color:#5b040e}.saboxplugin-socials.sabox-colored:1
# .sab-reddit{border-color:#992900}.saboxplugin-socials.sabox-colored:1
# .sab-rss{border-color:#a43b0a}.saboxplugin-socials.sabox-colored:1
# .sab-sharethis{border-color:#5d8420}.saboxplugin-socials.sabox-colored:1
# .sab-skype{border-color:#00658a}.saboxplugin-socials.sabox-colored:1
# .sab-soundcloud{border-color:#995200}.saboxplugin-socials.sabox-colored:1
# .sab-spotify{border-color:#0f612c}.saboxplugin-socials.sabox-colored:1
# .sab-stackoverflow{border-color:#a95009}.saboxplugin-socials.sabox-colored:1
# .sab-steam{border-color:#006388}.saboxplugin-socials.sabox-colored:1
# .sab-user_email{border-color:#b84e05}.saboxplugin-socials.sabox-colored:1
# .sab-stumbleUpon{border-color:#9b280e}.saboxplugin-socials.sabox-colored:1
# .sab-tumblr{border-color:#10151b}.saboxplugin-socials.sabox-colored:1
# .sab-twitter{border-color:#0967a0}.saboxplugin-socials.sabox-colored:1
# .sab-vimeo{border-color:#0d7091}.saboxplugin-socials.sabox-colored:1
# .sab-windows{border-color:#003f71}.saboxplugin-socials.sabox-colored:1
# .sab-whatsapp{border-color:#003f71}.saboxplugin-socials.sabox-colored:1
# .sab-wordpress{border-color:#0f3647}.saboxplugin-socials.sabox-colored:1
# .sab-yahoo{border-color:#14002d}.saboxplugin-socials.sabox-colored:1
# .sab-youtube{border-color:#900}.saboxplugin-socials.sabox-colored:1
# .sab-xing{border-color:#000202}.saboxplugin-socials.sabox-colored:1
# .sab-mixcloud{border-color:#2475a0}.saboxplugin-socials.sabox-colored:1
# .sab-vk{border-color:#243549}.saboxplugin-socials.sabox-colored:1
# .sab-medium{border-color:#00452c}.saboxplugin-socials.sabox-colored:1
# .sab-quora{border-color:#420e00}.saboxplugin-socials.sabox-colored:1
# .sab-meetup{border-color:#9b181c}.saboxplugin-socials.sabox-colored:1
# .sab-goodreads{border-color:#000}.saboxplugin-socials.sabox-colored:1
# .sab-snapchat{border-color:#999700}.saboxplugin-socials.sabox-colored:1
# .sab-500px{border-color:#00557f}.saboxplugin-socials.sabox-colored:1
# .sab-mastodont{border-color:#185886}.sabox-plus-item{margin-bottom:20px}@media:1
# screen:1
# (max-width:480px){.saboxplugin-wrap{text-align:center}.saboxplugin-wrap:1
# .saboxplugin-gravatar{float:none;padding:20px:1
# 0;text-align:center;margin:0:1
# auto;display:block}.saboxplugin-wrap:1
# img{float:none;display:inline-block;display:-moz-inline-stack;vertical-align:middle;zoom:1}.saboxplugin-wrap:1
# .saboxplugin-desc{margin:0:1
# 10px:1
# 20px;text-align:center}.saboxplugin-wrap:1
# .saboxplugin-authorname{text-align:center;margin:10px:1
# 20px}}body:1
# a,body:1
# a:hover{box-shadow:none;-webkit-box-shadow:none}a.sab-profile-edit{font-size:16px!important;line-height:1!important}.sab-edit-settings:1
# a,a.sab-profile-edit{color:#0073aa!important;box-shadow:none!important;-webkit-box-shadow:none!important}.sab-edit-settings{margin-right:15px;position:absolute;right:0;z-index:2;bottom:10px;line-height:20px}.sab-edit-settings:1
# i{margin-left:5px}.saboxplugin-socials{line-height:1!important}.rtl:1
# .saboxplugin-wrap:5
# .saboxplugin-gravatar{float:right}.rtl:1
# .saboxplugin-authorname{display:flex;align-items:center}.rtl:1
# .sab-profile-edit{margin-right:10px}.rtl:1
# .sab-edit-settings{right:auto;left:0}img.sab-custom-avatar{max-width:75px;}.saboxplugin-wrap:1
# {color:0:1
# !important;}.saboxplugin-wrap:2
# .saboxplugin-icon-grey:1
# {color:0;:1
# fill:0;}.saboxplugin-wrap:1
# a,.saboxplugin-wrap:1
# span:1
# {color:0;}.saboxplugin-wrap:1
# {margin-top:0px;:1
# margin-bottom:0px;:1
# 0px:2
# }.saboxplugin-wrap:1
# {font-size:18px;:1
# line-height:25px;}.saboxplugin-wrap:1
# p,:1
# {font-size:14px:1
# line-height:21px:1
# {font-size:14px;}.saboxplugin-wrap:1
# {width:18px;height:18px;}/*:1
# */:2
# q2w3_sidebar_options:1
# [{"sidebar":"sidebar","margin_top":10,"margin_bottom":20,"stop_id":"colophon","screen_max_width":0,"screen_max_height":0,"width_inherit":false,"refresh_interval":1500,"window_load_hook":false,"disable_mo_api":false,"widgets":["search-3","creek_latest_posts-2","do-etfw-2","text-2"]}];:1
# /*:2
# *//*:1
# sti_vars:1
# {"ajaxurl":"https:\/\/dolly.com\/blog\/wp-admin\/admin-ajax.php","selector":"img","title":"","summary":"","minWidth":"200","minHeight":"200","sharer":"https:\/\/dolly.com\/blog\/wp-content\/plugins\/share-this-image\/sharer.php","is_mobile":"","position":"image_hover","analytics":"","buttons":{"desktop":["facebook","twitter","linkedin","pinterest"],"mobile":["facebook","twitter","linkedin","pinterest"]},"twitterVia":"getdolly","appId":"","custom_data":[]};:1
# */vices.com/pagead/conversion.js">!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?:1
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;:1
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;:1
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,:1
# document,'script','//connect.facebook.net/en_US/fbevents.js');:1
# //:1
# Insert:1
# Facebook:1
# Pixel:1
# ID:1
# below.:1
# fbq('init',:1
# '842588449091347');:1
# fbq('track',:1
# 'PageView');defer:1
# src="//js.hs-scripts.com/3049473.js">(function(w,d,t,r,u){var:1
# f,n,i;w[u]=w[u]||[],f=function(){var:1
# o={ti:"5038210"};o.q=w[u],w[u]=new:1
# UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var:1
# s=this.readyState;s!=="loaded"!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");:1
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
